# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %pip install seaborn
import seaborn as sns
# %pip install wordcloud
from wordcloud import WordCloud
# %pip install matplotlib pandas

import warnings 

# %pip install openpyxl


warnings.filterwarnings("ignore")

colors = ["#85C1E9", "#F5B041", "#FF5733", "#7DCEA0", "#F4D03F",
          "#AF7AC5", "#BA4A00", "#F7DC6F", "#A93226", "#1ABC9C",
          "#F5B7B1", "#D5DBDB", "#F1948A", "#7FB3D5", "#A569BD"]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\samri\appdata\roaming\python\python311\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\program files\python311\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\samri\appdata\roaming\python\python311\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\program files\python311\lib\site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\program files\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\program files\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\program files\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\program files\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\samri\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\program files\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\program files\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\samri\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\samri\appdata\roaming\python\python311\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\samri\appdata\roaming\python\python311\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\samri\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in c:\users\samri\appdata\roaming\python\python311\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\program files\python311\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\program files\python311\lib\site-packages (from wordcloud) (10.3.0)
# Requirement already satisfied: matplotlib in c:\program files\python311\lib\site-packages (from wordcloud) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\program files\python311\lib\site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\program files\python311\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\program files\python311\lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\program files\python311\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\samri\appdata\roaming\python\python311\site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\program files\python311\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\samri\appdata\roaming\python\python311\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\samri\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\program files\python311\lib\site-packages (3.8.4)
# Requirement already satisfied: pandas in c:\users\samri\appdata\roaming\python\python311\site-packages (2.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\program files\python311\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\program files\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\program files\python311\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\program files\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in c:\program files\python311\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\samri\appdata\roaming\python\python311\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\program files\python311\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\program files\python311\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\samri\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\samri\appdata\roaming\python\python311\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\samri\appdata\roaming\python\python311\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\samri\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: openpyxl in c:\users\samri\appdata\roaming\python\python311\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\samri\appdata\roaming\python\python311\site-packages (from openpyxl) (2.0.0)

# %%
df = pd.read_excel(r"C:\Users\samri\Downloads\shopping_trends_updated.xlsx")


df.sample(5)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 2371         2372   67    Male          Socks     Clothing
# 440           441   20    Male          Shirt     Clothing
# 2161         2162   23    Male          Dress     Clothing
# 2740         2741   19  Female     Sunglasses  Accessories
# 671           672   38    Male         Jacket    Outerwear
#
#       Purchase Amount (USD)      Location Size     Color  Season  \
# 2371                     25       Indiana    M  Charcoal  Winter
# 440                      89      Oklahoma   XL    Maroon  Winter
# 2161                     69    Washington    S     Peach  Summer
# 2740                     70  Pennsylvania    M  Lavender  Summer
# 671                      30          Iowa    L     Black  Winter
#
#       Review Rating Subscription Status  Shipping Type Discount Applied  \
# 2371            3.7                  No   Next Day Air               No
# 440             3.5                 Yes   Store Pickup              Yes
# 2161            3.8                  No        Express               No
# 2740            4.9                  No  Free Shipping               No
# 671             4.7                 Yes        Express              Yes
#
#      Promo Code Used  Previous Purchases Payment Method Frequency of Purchases
# 2371              No                  28     Debit Card               Annually
# 440              Yes                  34     Debit Card            Fortnightly
# 2161              No                   5     Debit Card            Fortnightly
# 2740              No                  34  Bank Transfer            Fortnightly
# 671              Yes                  45           Cash                 Weekly

# %%
ax = df['Gender']. value_counts().plot(kind ='bar', rot=0, color = colors)
plt.show()

# %%
import matplotlib.pyplot as plt

count = df["Gender"].value_counts()
count.plot(kind='pie', colors=['#FF9999', '#66B3FF'], explode=(0, 0.1), autopct='%1.1f%%')

plt.xlabel('Gender', weight='bold')
plt.legend(title='Gender')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data=df['Age'], color='skyblue')
plt.show()

# %%
df["Category"].value_counts()
# Out:
# Category
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: count, dtype: int64

# %%
ax = df['Category'].value_counts().plot(kind='bar', color = colors,rot = 0)

# Annotating the bars with their height values
for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha='center')

# Corrected ylabel
plt.ylabel('Number of Occurrences', weight='bold')  # Use 'bold' instead of 'hold'
plt.xlabel('Categories', weight='bold')
plt.show()

# %%
plt.figure(figsize=(28, 6))
counts = df['Category'].value_counts()
explode = [0.1] * len(counts)

counts.plot(kind='pie', colors=colors, explode=explode, autopct='%1.1f%%')
plt.xlabel('Category', weight='bold')
plt.legend()
plt.show()

# %%
def get_pieChart(column):
    plt.figure(figsize=(20, 6))
    counts = df[column].value_counts()
    explode = [0] * (len(counts) - 1) + [0.1]
    counts.plot(kind='pie', colors=colors, explode=explode, autopct='%1.1f%%')
    plt.xlabel(column, weight='bold')
    plt.legend()
    plt.show()

get_pieChart("Subscription Status")

# %%
def get_pieChart(column):
    if column in df.columns:
        plt.figure(figsize=(20, 6))
        counts = df[column].value_counts()
        explode = [0] * (len(counts) - 1) + [0.1]
        counts.plot(kind='pie', colors=colors, explode=explode, autopct='%1.1f%%')
        plt.title(f'Pie Chart for {column}')
        plt.show()
    else:
        print(f"Column '{column}' not found in DataFrame.")

# %%
get_pieChart("Payment Method")

# %%
def getBarChart(column):
    plt.figure(figsize=(20, 6))
    ax = df[column].value_counts().plot(kind='bar', color=colors, rot=0)
    
    for p in ax.patches:
        ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha='center')
    
    plt.xlabel(column, weight='bold')
    plt.ylabel('Number of Occurrences', weight='bold')
    plt.show()

# %%
getBarChart("Payment Method")

# %%
getBarChart("Shipping Type")

# %%
getBarChart("Item Purchased")

# %%
plt.figure(figsize=(16, 8))
df['Item Purchased'].value_counts().sort_values().plot(
    kind='barh',
    color=sns.color_palette("tab10"),
    edgecolor="black"
)

plt.ylabel('Item Purchased', fontsize=16)
plt.xlabel('Number of Occurrences', fontsize=16)
plt.title('Item Purchased\n', fontsize=16)
plt.show()

# %%
df["Location"].value_counts()
# Out:
# Location
# Montana           96
# California        95
# Idaho             93
# Illinois          92
# Alabama           89
# Minnesota         88
# Nebraska          87
# New York          87
# Nevada            87
# Maryland          86
# Delaware          86
# Vermont           85
# Louisiana         84
# North Dakota      83
# Missouri          81
# West Virginia     81
# New Mexico        81
# Mississippi       80
# Indiana           79
# Georgia           79
# Kentucky          79
# Arkansas          79
# North Carolina    78
# Connecticut       78
# Virginia          77
# Ohio              77
# Tennessee         77
# Texas             77
# Maine             77
# South Carolina    76
# Colorado          75
# Oklahoma          75
# Wisconsin         75
# Oregon            74
# Pennsylvania      74
# Washington        73
# Michigan          73
# Alaska            72
# Massachusetts     72
# Wyoming           71
# Utah              71
# New Hampshire     71
# South Dakota      70
# Iowa              69
# Florida           68
# New Jersey        67
# Hawaii            65
# Arizona           65
# Kansas            63
# Rhode Island      63
# Name: count, dtype: int64

# %%
df["Size"].value_counts()
# Out:
# Size
# M     1755
# L     1053
# S      663
# XL     429
# Name: count, dtype: int64

# %%
df["Category"].value_counts()
df["Color"].value_counts()
df["Season"].value_counts()
# Out:
# Season
# Spring    999
# Fall      975
# Winter    971
# Summer    955
# Name: count, dtype: int64

# %%
text = " ".join(title for title in df["Frequency of Purchases"])
word_cloud = WordCloud(collocations=False, background_color='white').generate(text)
plt.axis("off")
plt.imshow(word_cloud)
plt.show()

# %%
plt.figure(figsize=(20, 6))

category_purchase_total = df.groupby('Category')['Purchase Amount (USD)'].sum()

category_purchase_total.plot(kind='area')

plt.title('Total Purchase Amount by Category')

plt.xlabel('Category')
plt.ylabel('Total Purchase Amount (USD)')

plt.xticks(rotation=45)
plt.show()

# %%
average_age = df['Age'].mean()
print("Average Age:", average_age)
# Out:
# Average Age: 44.06846153846154

# %%
df['Item Purchased'].mode()
df['Item Purchased'].mode()[0]
# Out:
# 'Blouse'

# %%
df[df['Gender'] == 'Male']['Item Purchased'].mode()
# Out:
# 0    Pants
# Name: Item Purchased, dtype: object

# %%
df[df['Gender'] == 'Male']['Item Purchased'].mode()
# Out:
# 0    Pants
# Name: Item Purchased, dtype: object

# %%
df[df['Gender'] == 'Female']['Item Purchased'].mode()
# Out:
# 0    Blouse
# Name: Item Purchased, dtype: object

# %%
most_common_season = df['Season'].mode()[0]
print("Most Common Season for Purchases:", most_common_season)
# Out:
# Most Common Season for Purchases: Spring

# %%
max_review_rating = df['Review Rating'].max()
min_review_rating = df['Review Rating'].min()
print("Maximum Review Rating:", max_review_rating)
print("Minimum Review Rating:", min_review_rating)
# Out:
# Maximum Review Rating: 5.0
# Minimum Review Rating: 2.5

# %%
common_category_low_rating_male_winter = df[(df['Gender'] == 'Male') &
                                           (df['Season'] == 'Winter') &
                                           (df['Review Rating'] < 3)]['Category'].mode()[0]
print("Most Common Category for Low-Rating Male Customers in Winter Season:", common_category_low_rating_male_winter)
# Out:
# Most Common Category for Low-Rating Male Customers in Winter Season: Clothing

# %%
subscription_promo_count = df[(df['Subscription Status'] == 'Yes') &
                             (df['Promo Code Used'] == 'Yes')]['Customer ID'].count()
print("Number of Customers with Subscription and Promo Code Used:", subscription_promo_count)
# Out:
# Number of Customers with Subscription and Promo Code Used: 1053
